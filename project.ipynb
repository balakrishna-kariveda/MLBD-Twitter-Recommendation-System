# %%
# !pip install numpy pandas faker scikit-learn nltk
# Out:
# Requirement already satisfied: numpy in /home/snt/Documents/M.Tech/Semester 3/Big Data/Project/.venv/lib/python3.12/site-packages (2.2.4)
# Requirement already satisfied: pandas in /home/snt/Documents/M.Tech/Semester 3/Big Data/Project/.venv/lib/python3.12/site-packages (2.2.3)
# Requirement already satisfied: faker in /home/snt/Documents/M.Tech/Semester 3/Big Data/Project/.venv/lib/python3.12/site-packages (37.1.0)
# Requirement already satisfied: scikit-learn in /home/snt/Documents/M.Tech/Semester 3/Big Data/Project/.venv/lib/python3.12/site-packages (1.6.1)
# Requirement already satisfied: nltk in /home/snt/Documents/M.Tech/Semester 3/Big Data/Project/.venv/lib/python3.12/site-packages (3.9.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/snt/Documents/M.Tech/Semester 3/Big Data/Project/.venv/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/snt/Documents/M.Tech/Semester 3/Big Data/Project/.venv/lib/python3.12/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/snt/Documents/M.Tech/Semester 3/Big Data/Project/.venv/lib/python3.12/site-packages (from pandas) (2025.2)
# Requirement already satisfied: scipy>=1.6.0 in /home/snt/Documents/M.Tech/Semester 3/Big Data/Project/.venv/lib/python3.12/site-packages (from scikit-learn) (1.15.2)
# Requirement already satisfied: joblib>=1.2.0 in /home/snt/Documents/M.Tech/Semester 3/Big Data/Project/.venv/lib/python3.12/site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/snt/Documents/M.Tech/Semester 3/Big Data/Project/.venv/lib/python3.12/site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: click in /home/snt/Documents/M.Tech/Semester 3/Big Data/Project/.venv/lib/python3.12/site-packages (from nltk) (8.1.8)
# Requirement already satisfied: regex>=2021.8.3 in /home/snt/Documents/M.Tech/Semester 3/Big Data/Project/.venv/lib/python3.12/site-packages (from nltk) (2024.11.6)
# Requirement already satisfied: tqdm in /home/snt/Documents/M.Tech/Semester 3/Big Data/Project/.venv/lib/python3.12/site-packages (from nltk) (4.67.1)
# Requirement already satisfied: six>=1.5 in /home/snt/Documents/M.Tech/Semester 3/Big Data/Project/.venv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
import numpy as np
import pandas as pd
from faker import Faker
from sklearn.cluster import KMeans
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import nltk
import re

# %%
# Initialize Faker and download NLTK resources
fake = Faker()
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /home/snt/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /home/snt/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %% [markdown]
# Data Generation

# %%
def generate_synthetic_data(num_users=1000, num_tweets=5000, num_interactions=20000, num_products=200):
    # Generate users
    users = pd.DataFrame([{
        'user_id': i,
        'join_date': fake.date_this_decade(),
        'location': fake.city(),
        'bio': fake.sentence(),
        'verified': np.random.choice([0, 1], p=[0.9, 0.1])
    } for i in range(num_users)])
    
    # Generate tweets with topics
    topics = ['politics', 'technology', 'sports', 'entertainment', 'science']
    tweets = pd.DataFrame([{
        'tweet_id': i,
        'author_id': np.random.randint(0, num_users),
        'content': fake.text(max_nb_chars=280),
        'timestamp': fake.date_time_this_year(),
        'topic': np.random.choice(topics),
        'likes': np.random.poisson(lam=50),
        'retweets': np.random.poisson(lam=10)
    } for i in range(num_tweets)])
    
    # Generate interactions
    interactions = pd.DataFrame([{
        'user_id': np.random.randint(0, num_users),
        'tweet_id': np.random.randint(0, num_tweets),
        'interaction_type': np.random.choice(['view', 'like', 'retweet', 'reply'], 
            p=[0.7, 0.2, 0.08, 0.02]),
        'timestamp': fake.date_time_this_year()
    } for _ in range(num_interactions)])
    
    # Generate products
    product_categories = ['electronics', 'books', 'fashion', 'home goods', 'sports equipment']
    products = pd.DataFrame([{
        'product_id': i,
        'product_name': fake.catch_phrase(),
        'category': np.random.choice(product_categories),
        'price': np.random.uniform(10, 500),
        'rating': np.random.normal(4.5, 0.5)
    } for i in range(num_products)])
    
    # Add product mentions to tweets
    tweets['mentioned_product'] = np.random.choice(
        [-1] + list(range(num_products)), 
        size=num_tweets,
        p=[0.7] + [0.3/num_products]*num_products
    )
    
    return users, tweets, interactions, products

# %% [markdown]
# Generate synthetic data

# %%
users, tweets, interactions, products = generate_synthetic_data()

# %%
users
# Out:
#      user_id   join_date           location  \
# 0          0  2025-04-03        Michelleton
# 1          1  2023-01-30        Mauricefurt
# 2          2  2020-10-15        Port Robert
# 3          3  2021-01-31  West Brittanyland
# 4          4  2021-08-31       Nicholasside
# ..       ...         ...                ...
# 995      995  2023-02-21        Mullenmouth
# 996      996  2020-07-07          Aaronbury
# 997      997  2020-05-14        Shannonbury
# 998      998  2023-04-04         Ellenhaven
# 999      999  2023-06-15     West Chrisfurt
#
#                                                   bio  verified
# 0         Present detail effort break right bad cell.         0
# 1                                  Short player lose.         0
# 2       Character ok him space big well year require.         1
# 3                   Others who field here write just.         0
# 4    Audience boy rather event position teacher high.         1
# ..                                                ...       ...
# 995                     Eight human class woman film.         0
# 996   Here collection reflect least give reveal area.         0
# 997                       Performance above eight in.         0
# 998                 Serve expert here police in step.         0
# 999                         Trouble there huge carry.         0
#
# [1000 rows x 5 columns]

# %%
tweets
# Out:
#       tweet_id  author_id                                            content  \
# 0            0        658  Leg actually tonight training. For success spe...
# 1            1        475  Improve wife nature way teacher red seven. He ...
# 2            2        883  Area control market fall sea exactly school be...
# 3            3        675  Someone head want nearly must.\nChoose electio...
# 4            4        698  Yard glass present art alone expect. Stock rel...
# ...        ...        ...                                                ...
# 4995      4995        603  Near third through trial. Red Republican event...
# 4996      4996        324  While degree even now material daughter. Manag...
# 4997      4997        226  Over reflect oil. Ground there student physica...
# 4998      4998        888  Claim raise though my number administration ch...
# 4999      4999        416  Themselves near determine baby pass sea. Sugge...
#
#                       timestamp          topic  likes  retweets  \
# 0    2025-01-28 08:48:32.046108       politics     55         7
# 1    2025-03-06 08:24:28.337057         sports     56         7
# 2    2025-03-22 08:24:05.836072         sports     54         9
# 3    2025-03-07 10:17:34.801566         sports     59        13
# 4    2025-04-01 13:39:31.088047         sports     40         7
# ...                         ...            ...    ...       ...
# 4995 2025-03-27 12:42:27.266684         sports     50        10
# 4996 2025-02-04 15:10:40.600136         sports     58        12
# 4997 2025-03-18 22:01:32.970505         sports     45        11
# 4998 2025-02-28 20:32:49.597584  entertainment     45        13
# 4999 2025-02-12 19:20:26.052606  entertainment     55         6
#
#       mentioned_product
# 0                    -1
# 1                    -1
# 2                    -1
# 3                    -1
# 4                    -1
# ...                 ...
# 4995                 -1
# 4996                179
# 4997                199
# 4998                 71
# 4999                 -1
#
# [5000 rows x 8 columns]

# %%
interactions
# Out:
#        user_id  tweet_id interaction_type                  timestamp
# 0           12       345             view 2025-03-01 23:07:13.836686
# 1          894      4922             view 2025-02-07 05:20:40.259222
# 2          876      1890             view 2025-03-24 12:06:41.237463
# 3          703      1737             view 2025-01-24 06:46:44.487447
# 4          634      3036          retweet 2025-01-08 09:01:58.078832
# ...        ...       ...              ...                        ...
# 19995      836      2473             view 2025-01-28 06:38:39.232970
# 19996      134      3630             view 2025-02-14 21:20:12.272506
# 19997      931      4561             view 2025-02-09 11:42:40.116670
# 19998      865      3697             view 2025-01-01 13:17:47.508510
# 19999      352      2951             view 2025-04-08 06:58:24.108287
#
# [20000 rows x 4 columns]

# %%
products
# Out:
#      product_id                              product_name          category  \
# 0             0        Centralized discrete collaboration             books
# 1             1     Adaptive coherent process improvement             books
# 2             2         Realigned 5thgeneration structure        home goods
# 3             3  Mandatory bi-directional instruction set           fashion
# 4             4              Versatile regional workforce             books
# ..          ...                                       ...               ...
# 195         195      Multi-channeled zero-defect solution        home goods
# 196         196               Adaptive multimedia adapter  sports equipment
# 197         197   Ameliorated context-sensitive migration           fashion
# 198         198                 Total 24hour productivity           fashion
# 199         199     Re-engineered demand-driven hierarchy  sports equipment
#
#           price    rating
# 0    189.483446  4.546454
# 1    476.467030  4.453028
# 2    410.641902  4.610612
# 3     20.497259  4.143088
# 4    367.512114  4.337192
# ..          ...       ...
# 195  468.258925  5.445938
# 196   49.866497  4.082463
# 197  106.012140  4.955438
# 198   95.658405  4.530035
# 199  432.707973  4.745048
#
# [200 rows x 5 columns]

# %% [markdown]
# User Clustering

# %%
def preprocess_text(text):
    text = text.lower()
    text = re.sub(r'[^\w\s]', '', text)
    tokens = word_tokenize(text)
    tokens = [word for word in tokens if word not in stopwords.words('english')]
    return ' '.join(tokens)

# %% [markdown]
# Create user-topic matrix

# %%
user_topics = interactions.merge(tweets, on='tweet_id')
user_topics = user_topics.groupby(['user_id', 'topic']).size().unstack(fill_value=0)

# %%
user_topics
# Out:
# topic    entertainment  politics  science  sports  technology
# user_id
# 0                    4         5        3       4           3
# 1                    5         2        3       6           3
# 2                    4         5        6       4           5
# 3                    2         6        4       6           4
# 4                    6         2        4       4           7
# ...                ...       ...      ...     ...         ...
# 995                  0         4        0       3           4
# 996                  1         5        4       6           4
# 997                  4         3        1       4           8
# 998                  1         6        5       1           5
# 999                  4         2        5       7           3
#
# [1000 rows x 5 columns]

# %% [markdown]
# Cluster users

# %%
kmeans = KMeans(n_clusters=5, random_state=42)
clusters = kmeans.fit_predict(user_topics)
user_topics['cluster'] = clusters
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[38], line 2
#       1 kmeans = KMeans(n_clusters=5, random_state=42)
# ----> 2 clusters = kmeans.fit_predict(user_topics)
#       3 user_topics['cluster'] = clusters
#
# File ~/Documents/M.Tech/Semester 3/Big Data/Project/.venv/lib/python3.12/site-packages/sklearn/cluster/_kmeans.py:1064, in _BaseKMeans.fit_predict(self, X, y, sample_weight)
#    1041 def fit_predict(self, X, y=None, sample_weight=None):
#    1042     """Compute cluster centers and predict cluster index for each sample.
#    1043
#    1044     Convenience method; equivalent to calling fit(X) followed by
#    (...)   1062         Index of the cluster each sample belongs to.
#    1063     """
# -> 1064     return self.fit(X, sample_weight=sample_weight).labels_
#
# File ~/Documents/M.Tech/Semester 3/Big Data/Project/.venv/lib/python3.12/site-packages/sklearn/base.py:1389, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1382     estimator._validate_params()
#    1384 with config_context(
#    1385     skip_parameter_validation=(
#    1386         prefer_skip_nested_validation or global_skip_validation
#    1387     )
#    1388 ):
# -> 1389     return fit_method(estimator, *args, **kwargs)
#
# File ~/Documents/M.Tech/Semester 3/Big Data/Project/.venv/lib/python3.12/site-packages/sklearn/cluster/_kmeans.py:1454, in KMeans.fit(self, X, y, sample_weight)
#    1426 @_fit_context(prefer_skip_nested_validation=True)
#    1427 def fit(self, X, y=None, sample_weight=None):
#    1428     """Compute k-means clustering.
#    1429
#    1430     Parameters
#    (...)   1452         Fitted estimator.
#    1453     """
# -> 1454     X = validate_data(
#    1455         self,
#    1456         X,
#    1457         accept_sparse="csr",
#    1458         dtype=[np.float64, np.float32],
#    1459         order="C",
#    1460         copy=self.copy_x,
#    1461         accept_large_sparse=False,
#    1462     )
#    1464     self._check_params_vs_input(X)
#    1466     random_state = check_random_state(self.random_state)
#
# File ~/Documents/M.Tech/Semester 3/Big Data/Project/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2919, in validate_data(_estimator, X, y, reset, validate_separately, skip_check_array, **check_params)
#    2835 def validate_data(
#    2836     _estimator,
#    2837     /,
#    (...)   2843     **check_params,
#    2844 ):
#    2845     """Validate input data and set or check feature names and counts of the input.
#    2846
#    2847     This helper function should be used in an estimator that requires input
#    (...)   2917         validated.
#    2918     """
# -> 2919     _check_feature_names(_estimator, X, reset=reset)
#    2920     tags = get_tags(_estimator)
#    2921     if y is None and tags.target_tags.required:
#
# File ~/Documents/M.Tech/Semester 3/Big Data/Project/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2715, in _check_feature_names(estimator, X, reset)
#    2688 """Set or check the `feature_names_in_` attribute of an estimator.
#    2689
#    2690 .. versionadded:: 1.0
#    (...)   2711        should set `reset=False`.
#    2712 """
#    2714 if reset:
# -> 2715     feature_names_in = _get_feature_names(X)
#    2716     if feature_names_in is not None:
#    2717         estimator.feature_names_in_ = feature_names_in
#
# File ~/Documents/M.Tech/Semester 3/Big Data/Project/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2417, in _get_feature_names(X)
#    2415 # mixed type of string and non-string is not supported
#    2416 if len(types) > 1 and "str" in types:
# -> 2417     raise TypeError(
#    2418         "Feature names are only supported if all input features have string names, "
#    2419         f"but your input has {types} as feature name / column name types. "
#    2420         "If you want feature names to be stored and validated, you must convert "
#    2421         "them all to strings, by using X.columns = X.columns.astype(str) for "
#    2422         "example. Otherwise you can remove feature / column names from your input "
#    2423         "data, or convert them all to a non-string data type."
#    2424     )
#    2426 # Only feature names of all strings are supported
#    2427 if len(types) == 1 and types[0] == "str":
#
# TypeError: Feature names are only supported if all input features have string names, but your input has ['str', 'str_'] as feature name / column name types. If you want feature names to be stored and validated, you must convert them all to strings, by using X.columns = X.columns.astype(str) for example. Otherwise you can remove feature / column names from your input data, or convert them all to a non-string data type.

# %% [markdown]
# Candidate Sourcing

# %%
def get_candidate_tweets(target_user_id, tweets, user_topics, num_candidates=500):
    # Get user cluster
    cluster = user_topics.loc[target_user_id]['cluster']
    
    # Get tweets from same cluster users
    cluster_users = user_topics[user_topics['cluster'] == cluster].index
    cluster_tweets = tweets[tweets['author_id'].isin(cluster_users)]
    
    # Get popular tweets from all clusters
    popular_tweets = tweets.sort_values('likes', ascending=False).head(200)
    
    # Combine candidates
    candidates = pd.concat([cluster_tweets, popular_tweets]).drop_duplicates()
    return candidates.sample(min(num_candidates, len(candidates)))

# %% [markdown]
# Ranking Model

# %% [markdown]
# Prepare training data

# %%
interactions['target'] = interactions['interaction_type'].apply(
    lambda x: 1 if x in ['like', 'retweet', 'reply'] else 0)

merged_data = interactions.merge(users, on='user_id')
merged_data = merged_data.merge(tweets, on='tweet_id')

# %%
users.rename(columns={'user_id': 'author_id'}, inplace=True)

# %% [markdown]
# Feature engineering

# %%
features = merged_data[[
    'verified', 'likes', 'retweets',
    'topic' 
]]
target = merged_data['target']

# %% [markdown]
# Preprocessing pipeline

# %%
preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), ['verified', 'likes', 'retweets']),
        ('cat', OneHotEncoder(), ['topic'])
])

# %% [markdown]
# Build model pipeline

# %%
model = Pipeline([
    ('preprocessor', preprocessor),
    ('classifier', RandomForestClassifier(n_estimators=100, class_weight='balanced'))
])

# %% [markdown]
# Train model

# %%
X_train, X_test, y_train, y_test = train_test_split(
    features, target, test_size=0.2, random_state=42)
model.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num', StandardScaler(),
#                                                   ['verified', 'likes',
#                                                    'retweets']),
#                                                  ('cat', OneHotEncoder(),
#                                                   ['topic'])])),
#                 ('classifier',
#                  RandomForestClassifier(class_weight='balanced'))])

# %% [markdown]
# Post-Rules Application

# %%
def apply_post_rules(ranked_tweets, max_authors=3, banned_keywords=['spam', 'scam']):
    # Filter banned keywords
    clean_tweets = ranked_tweets[
        ~ranked_tweets['content'].str.contains('|'.join(banned_keywords), case=False)]
    
    # Limit authors
    clean_tweets = clean_tweets.sort_values(by='author_id', 
        key=lambda x: x.map(x.value_counts()))
    clean_tweets = clean_tweets.drop_duplicates(subset='author_id', keep='first')
    
    # Ensure topic diversity
    final_tweets = clean_tweets.sort_values(
        by=['predicted_score', 'topic'], 
        ascending=[False, True]
    ).head(50)
    
    return final_tweets

# %%
target_user = np.random.choice(users['author_id'])
candidates = get_candidate_tweets(target_user, tweets, user_topics)
candidates.merge(users, on='author_id')
# Out:
#      tweet_id  author_id                                            content  \
# 0        4184         88  Drug hear office special blood official after ...
# 1        4407        677  Environmental about kid wife. Each whatever on...
# 2        3094        857  Stop of economy out pressure minute task.\nThe...
# 3        4907        580  Win and skill history. Everyone new modern rat...
# 4        3586        828  Century I reduce enough writer future major. R...
# ..        ...        ...                                                ...
# 495      1717        635  Class adult lead both. Mouth woman decade toni...
# 496       285        780  Land institution executive religious. Third te...
# 497       480        824  Relationship high current. Only position press...
# 498      2820         28  Next not college painting follow next availabl...
# 499      3462        879  Education theory spring mother drop dream. Hug...
#
#                      timestamp       topic  likes  retweets  \
# 0   2025-01-21 05:58:52.770650     science     62        10
# 1   2025-02-21 15:09:39.840482  technology     48        14
# 2   2025-04-14 10:03:20.134209      sports     59         6
# 3   2025-02-13 23:57:17.760742     science     41        10
# 4   2025-01-17 21:44:25.938478  technology     55         8
# ..                         ...         ...    ...       ...
# 495 2025-03-08 10:28:06.931328     science     51         9
# 496 2025-03-05 14:15:29.999519      sports     43         8
# 497 2025-03-12 22:49:38.643512      sports     46        12
# 498 2025-03-18 15:41:14.666482      sports     54        12
# 499 2025-04-20 10:47:04.924066    politics     46        10
#
#      mentioned_product   join_date             location  \
# 0                   -1  2022-09-17  East Cassandraburgh
# 1                  146  2023-02-17          North Emily
# 2                   -1  2024-09-07          Johnsonbury
# 3                   44  2024-11-24          Tiffanyport
# 4                   -1  2023-01-03       South Juanfort
# ..                 ...         ...                  ...
# 495                 -1  2024-12-19      West Mariashire
# 496                154  2022-12-11  New Victoriaborough
# 497                  8  2025-03-25  North Michelleville
# 498                 -1  2021-04-16           Nelsonview
# 499                 33  2022-10-04          Port Denise
#
#                                                    bio  verified
# 0                        With left likely first paper.         0
# 1    Threat put well question throughout marriage p...         0
# 2                Budget bill thousand oil speech read.         0
# 3    Drive international college each hot someone p...         0
# 4                              Imagine from it I wish.         0
# ..                                                 ...       ...
# 495                     Appear economy Congress still.         0
# 496                Particularly arrive feeling school.         0
# 497                            Help itself back heart.         0
# 498                              Part owner full turn.         0
# 499             Away before still exactly soldier per.         0
#
# [500 rows x 12 columns]

# %%
def recommend_products(target_user_id, user_topics, tweets, products, top_n=5):
    # Get user cluster
    cluster = user_topics.loc[target_user_id]['cluster']
    
    # Get popular products in cluster
    cluster_tweets = tweets[tweets['author_id'].isin(
        user_topics[user_topics['cluster'] == cluster].index
    )]
    product_mentions = cluster_tweets[cluster_tweets['mentioned_product'] != -1]
    
    # Get top products by engagement
    product_engagement = product_mentions.merge(
        interactions, on='tweet_id'
    ).groupby('mentioned_product').size().reset_index(name='counts')
    
    # Merge with product details and sort
    recommendations = product_engagement.merge(
        products, left_on='mentioned_product', right_on='product_id'
    ).sort_values(['counts', 'rating'], ascending=False)
    
    return recommendations.head(top_n)

# %% [markdown]
# Full Pipeline

# %%
def recommend_tweets(target_user_id, users, tweets, interactions, model):
    # Step 1: Candidate sourcing
    candidates = get_candidate_tweets(target_user_id, tweets, user_topics)
    candidates = candidates.merge(users, on='author_id')
    
    # Step 2: Feature preparation
    candidate_features = candidates[[
        'verified', 'likes', 'retweets', 'topic'
    ]]
    
    # Step 3: Ranking predictions
    predictions = model.predict_proba(candidate_features)[:, 1]
    candidates['predicted_score'] = predictions
    
    # Step 4: Apply post-rules
    ranked_tweets = candidates.sort_values('predicted_score', ascending=False)
    final_recommendations = apply_post_rules(ranked_tweets)
    
    return final_recommendations

# %%
target_user = np.random.choice(users['author_id'])
recommendations = recommend_tweets(target_user, users, tweets, interactions, model)
product_recommendations = recommend_products(target_user, user_topics, tweets, products)
print(f"Tweet Recommendations for user {target_user}:")
print(recommendations[['tweet_id', 'content', 'predicted_score']].head(10))

print(f"Product Recommendations for user {target_user}:")
print(product_recommendations[['product_id', 'product_name', 'category', 'rating']].head(10))
# Out:
# Tweet Recommendations for user 502:
#      tweet_id                                            content  \
# 384       579  Hair grow letter sure eat two early factor. Re...
# 161      2019  Edge whom design.\nWhy wide later professional...
# 312       499  Use character under development time indeed wa...
# 7        1056  For perform minute rate no rather page say. So...
# 383      4697  Local weight training customer must now. Contr...
# 273      1561  West business might young. Generation hundred ...
# 340      1788  Together good society remain should miss style...
# 465      1174  Hit beat old budget blue. Director ok never do...
# 106      1453  Six whom task admit everybody entire able. Sub...
# 21        968  Agent professional outside fill world some. At...
#
#      predicted_score
# 384         0.976758
# 161         0.963656
# 312         0.920292
# 7           0.871118
# 383         0.854440
# 273         0.822369
# 340         0.819907
# 465         0.796780
# 106         0.762767
# 21          0.744236
# Product Recommendations for user 502:
#      product_id                                       product_name  \
# 53           68                         Cloned exuding open system
# 138         185              Balanced client-server implementation
# 100         131             Multi-channeled asymmetric application
# 90          118  De-engineered attitude-oriented Graphical User...
# 11           17  Configurable client-driven artificial intellig...
#
#              category    rating
# 53              books  4.300843
# 138        home goods  4.895410
# 100             books  4.401576
# 90   sports equipment  4.263975
# 11            fashion  3.920975
